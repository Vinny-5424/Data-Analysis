# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Charts

# %% [markdown]
# ## 1. Line Chart

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# To customize its plot, it would use the array index as its x-axis unless the x-axis is stated
years = [2010, 2011, 2012, 2013, 2014, 2015]

plt.plot(years, yield_apples)
plt.show()

# %%
plt.plot(years, yield_apples)
plt.ylabel("Year")
plt.xlabel("Yield (tons per hectare)")
plt.show()

# %% [markdown]
# ### Plotting Multiple lines

# %%
yrs = range(2000, 2012)
orange = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]

plt.plot(yrs,apples)
plt.plot(yrs, orange)
plt.xlabel("Years")
plt.ylabel("Yield (tons per hectare)")
plt.title("Crop Yield in Boson")
plt.legend(["Apples", "Oranges"])
plt.show()

# %% [markdown]
# ### Styling lines and markers
# * `c`: to set line colour
# * `ls`: Choose a style(solid or dashed) of a line
# * `lw`: Set width of a line
# * `ms`: Set marker size
# * `mec`: Set the edge colour of a marker
# * `mew`: Marker edge width
# * `mfc`: Set marker fill colour
# * `alpha`: Opacity of the plot

# %%
yrs = range(2000, 2012)
orange = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]

plt.plot(yrs, apples, marker='s', c='b', ls='-', lw=2, mew='2', mec='navy')
plt.plot(yrs, orange, marker='o', c='r', ls='--', lw=3, ms=10, alpha=0.5)
plt.xlabel("Years")
plt.ylabel("Yield (tons per hectare)")
plt.title("Crop Yield in Boson")
plt.legend(["Apples", "Oranges"])
plt.show()

# %%
plt.figure(figsize=(4, 3))

plt.plot(yrs, orange, 'or')
plt.title("Yield of  orange (ton per hectare)")
plt.show()

# %% [markdown]
# ### Improving Default Style using seaborn

# %%
# 1. Whitegrid

sns.set_style("whitegrid")

plt.plot(yrs, apples, "s-b")
plt.plot(yrs, orange, "o--r")

plt.xlabel("Years")
plt.ylabel("Yield(tons per hectare)")

plt.title("Crop Yield in Boson")
plt.legend(["Apples", "Oranges"])

plt.show()

# %%
# 2. Darkgrid

sns.set_style("darkgrid")

plt.plot(yrs, apples, "s-b")
plt.plot(yrs, orange, "o--r")

plt.xlabel("Years")
plt.ylabel("Yield(tons per hectare)")

plt.title("Crop Yield in Boson")
plt.legend(["Apples", "Oranges"])

plt.show()

# %% [markdown]
# ### Editing the deafault size of Matplotlib

# %%
import matplotlib

# matplotlib.rcParams

# %%
# Ways to manipulate it permanently
matplotlib.rcParams["font.size"] = 14
matplotlib.rcParams["figure.figsize"] = (9, 5)
matplotlib.rcParams["figure.facecolor"] = '#00000000'

# %% [markdown]
# ## 2. Scatter plot
# It is basically used for random data(data that are not linear)

# %%
# from sklearn.datasets import load_iris
# import pandas as pd

# # Load the dataset bunch object
# iris_bunch = load_iris()

# # Convert the numerical data into a pandas DataFrame
# iris_df = pd.DataFrame(data=iris_bunch.data, columns=iris_bunch.feature_names)

# # Add the target column (the flower species as integers 0, 1, 2)
# iris_df['species'] = iris_bunch.target

# # Optional: Map the numbers to the actual text names
# species_names = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}
# iris_df['species'] = iris_df['species'].map(species_names)

# # dropping the species
# # iris_df = iris_df.drop('species', axis=1)

# # View the final dataset
# iris_df

# Convert to csv
# iris_df.to_csv("iris.csv")

# %%
flowers_df = pd.read_csv("iris.csv")
flowers_df
# Out:
#      Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0             0                5.1               3.5                1.4
# 1             1                4.9               3.0                1.4
# 2             2                4.7               3.2                1.3
# 3             3                4.6               3.1                1.5
# 4             4                5.0               3.6                1.4
# ..          ...                ...               ...                ...
# 145         145                6.7               3.0                5.2
# 146         146                6.3               2.5                5.0
# 147         147                6.5               3.0                5.2
# 148         148                6.2               3.4                5.4
# 149         149                5.9               3.0                5.1
#
#      petal width (cm)    species
# 0                 0.2     setosa
# 1                 0.2     setosa
# ...

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(x=flowers_df["sepal length (cm)"], y=flowers_df["sepal width (cm)"])
plt.xlabel("Sepal Length(cm)")
plt.ylabel("Sepal Width(cm)")
plt.show()

# %% [markdown]
# ### Adding hues

# %%
sns.scatterplot(x=flowers_df["sepal length (cm)"], y=flowers_df["sepal width (cm)"], hue=flowers_df["species"], s=50)
plt.show()

# %% [markdown]
# ### Customizing Seaborn Figures
# Since Seaborn uses matplotlib's plotting functions internally, we can use functions like `plt.figure`, `plt.title`

# %%
sns.scatterplot(x=flowers_df["sepal length (cm)"], y=flowers_df["sepal width (cm)"], hue=flowers_df["species"], s=50)
plt.title("Sepal Dimensions")
plt.figure(figsize=(12, 6))

plt.show();

# %% [markdown]
# ## 3. Histogram

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df["sepal width (cm)"])
plt.show()

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df["sepal width (cm)"], bins=5)
plt.show()

# %% [markdown]
# ### Multile Histogram

# %%
setosa_df = flowers_df[flowers_df["species"] == "setosa"]
versicolour_df= flowers_df[flowers_df["species"] == "versicolor"]
viginica_df = flowers_df[flowers_df["species"] == "viginica"]

plt.hist(setosa_df["sepal width (cm)"], alpha=0.4, bins=np.arange(2, 5, 0.25))
plt.hist(versicolour_df["sepal width (cm)"], alpha=0.4, bins=np.arange(2, 5, 0.25))
plt.title("Distribution of Sepal Width")
plt.legend(["Setosa", "Versicolour"]);

plt.show()

# %% [markdown]
# #### We can stack multiple hists on top of one another

# %%
plt.title("Distribution of Sepal Width")
plt.hist([versicolour_df["sepal width (cm)"], setosa_df["sepal width (cm)"], versicolour_df["sepal width (cm)"]],
         bins=np.arange(2, 5, 0.25),
        stacked=True)
plt.legend(["Setosa", "Versicolour", "Virginica"]);

plt.show()

# %% [markdown]
# ## 4. Bar Chart
#
# Bar Charts are similar to the line charts i.e they show a sequence of value, however a bar is shown for each value, rather than points connected y lines. we can use the `plt.bar` function to draw a bar chart.

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

plt.bar(years, oranges);
plt.show()

# %%
plt.plot(years, oranges, "r--o")
plt.bar(years, oranges);
plt.title("Yield of Oranges")
plt.show()

# %% [markdown]
# #### Like histograms, bars can also be stacked on top of one another. we use `bottom` argument to `plt.bar` to achieve this.

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples);
plt.title("Yield of Oranges and Apples")
plt.show()

# %% [markdown]
# ### Bar Plots with Averages

# %%
# import pandas as pd
# import numpy as np

# # Set random seed so your numbers are consistent
# np.random.seed(42)

# # Generate baseline statistical rows matching the standard layout
# n_rows = 244
# total_bills = np.round(np.random.gamma(shape=5, scale=4, size=n_rows) + 3, 2)
# tips = np.round(total_bills * np.random.uniform(0.10, 0.20, size=n_rows), 2)
# sexes = np.random.choice(['Male', 'Female'], size=n_rows, p=[0.64, 0.36])
# smokers = np.random.choice(['No', 'Yes'], size=n_rows, p=[0.62, 0.38])
# days = np.random.choice(['Sun', 'Sat', 'Thur', 'Fri'], size=n_rows, p=[0.31, 0.36, 0.25, 0.08])
# times = np.where((days == 'Thur') | (days == 'Fri'), 
#                  np.random.choice(['Lunch', 'Dinner'], size=n_rows, p=[0.7, 0.3]), 'Dinner')
# sizes = np.random.choice([1, 2, 3, 4, 5, 6], size=n_rows, p=[0.02, 0.64, 0.15, 0.15, 0.02, 0.02])

# # Build the DataFrame structured exactly like Aakash's tutorial dataset
# df_tips = pd.DataFrame({
#     'total_bill': total_bills,
#     'tip': tips,
#     'sex': sexes,
#     'smoker': smokers,
#     'day': days,
#     'time': times,
#     'size': sizes
# })

# # Save directly to your current working folder
# df_tips.to_csv("tips.csv", index=False)

# print(f"File completely generated successfully offline!")
# print(f"Total rows found in file: {len(df_tips)}")
# df_tips.head()

# %%
tips = pd.read_csv("tips.csv")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         18.20  3.63    Male     No   Sun  Dinner     2
# 1         57.47  6.36    Male    Yes   Fri  Dinner     6
# 2         14.06  1.73    Male     No  Thur   Lunch     2
# 3          8.86  1.73    Male    Yes  Thur   Lunch     1
# 4         19.71  3.86    Male     No   Sat  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       16.74  2.46  Female     No   Sun  Dinner     3
# 240        8.31  0.86    Male    Yes   Fri  Dinner     2
# 241       13.28  2.24    Male     No  Thur   Lunch     2
# 242       30.26  4.48  Female    Yes   Sun  Dinner     6
# 243       24.61  2.77    Male    Yes   Sat  Dinner     2
#
# [244 rows x 7 columns]

# %%
bill_avg_df = tips.groupby('day')[["total_bill"]].mean()
bill_avg_df
# Out:
#       total_bill
# day
# Fri    24.982778
# Sat    21.983977
# Sun    21.793418
# Thur   22.525932

# %%
plt.bar(bill_avg_df.index, bill_avg_df.total_bill)
plt.show()

# %%
# Using seaborn to bypass the coding of the average bill for each day
sns.barplot(x='day', y="total_bill", data=tips)
plt.show()

# %%
sns.barplot(x='day', y="total_bill", hue="sex", data=tips)
plt.show()

# %% [markdown]
# #### You can make the bars horizontal by switching the axes.

# %%
sns.barplot(x="total_bill", y="day", hue="sex", data=tips)
plt.show()

# %% [markdown]
# ## 5. Heatmap
# A heatmap is used to visualize 2-dimensional data like a matrix or a table using colours.

# %%
# import pandas as pd
# import numpy as np

# # Exact passenger counts for the classic 1949-1960 Flights dataset
# passenger_matrix = [
#     [112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118], # 1949
#     [115, 126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140], # 1950
#     [145, 150, 178, 163, 172, 178, 199, 199, 184, 162, 146, 166], # 1951
#     [171, 180, 193, 181, 183, 218, 230, 242, 209, 191, 172, 194], # 1952
#     [196, 196, 236, 235, 229, 243, 264, 272, 237, 211, 180, 201], # 1953
#     [204, 188, 235, 227, 234, 264, 302, 293, 259, 229, 203, 229], # 1954
#     [242, 233, 267, 269, 270, 315, 364, 347, 312, 274, 237, 278], # 1955
#     [284, 277, 317, 313, 318, 374, 413, 405, 355, 306, 271, 306], # 1956
#     [315, 301, 356, 348, 355, 422, 465, 467, 404, 347, 305, 336], # 1957
#     [340, 318, 362, 348, 363, 435, 491, 505, 404, 359, 310, 337], # 1958
#     [360, 342, 406, 396, 420, 472, 548, 559, 463, 407, 362, 405], # 1959
#     [417, 391, 419, 461, 472, 535, 622, 606, 508, 461, 390, 432]  # 1960
# ]

# months = ["January", "February", "March", "April", "May", "June", 
#           "July", "August", "September", "October", "November", "December"]
# years = list(range(1949, 1961))

# # Unroll the matrix into tabular CSV formatting
# data_rows = []
# for i, year in enumerate(years):
#     for j, month in enumerate(months):
#         data_rows.append([year, month, passenger_matrix[i][j]])

# # Save into the exact schema expected by the course
# df_flights = pd.DataFrame(data_rows, columns=['year', 'month', 'passengers'])
# df_flights.to_csv("flights.csv", index=False)

# print(f"Success! Generated 'flights.csv' offline with {len(df_flights)} rows.")

# %%
df_flights = pd.read_csv("flights.csv")
df_flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
plt.plot(df_flights.passengers)
plt.show()

#This kind of charts is not suitable for this kind of dataset

# %%
flights = df_flights.pivot(index="month", columns="year", values="passengers")
flights
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# April       129   135   163   181   235   227   269   313   348   348   396
# August      148   170   199   242   272   293   347   405   467   505   559
# December    118   140   166   194   201   229   278   306   336   337   405
# February    118   126   150   180   196   188   233   277   301   318   342
# January     112   115   145   171   196   204   242   284   315   340   360
# July        148   170   199   230   264   302   364   413   465   491   548
# June        135   149   178   218   243   264   315   374   422   435   472
# March       132   141   178   193   236   235   267   317   356   362   406
# May         121   125   172   183   229   234   270   318   355   363   420
# November    104   114   146   172   180   203   237   271   305   310   362
# October     119   133   162   191   211   229   274   306   347   359   407
# ...

# %%
plt.title("No. of passengers(1000s)")
sns.heatmap(flights)
plt.show()

# %% [markdown]
# #### To show more details

# %%
plt.title("No. of passengers(1000s)")
sns.heatmap(flights, fmt="d", annot=True, cmap="Blues")
plt.show()

# %% [markdown]
# # Images

# %%
# import urllib.request
# from PIL import Image
# import numpy as np
# import matplotlib.pyplot as plt

# # 1. Aakash's exact Imgur image source link
# url = 'https://i.imgur.com/SkPbq.jpg'
# filename = 'chart.jpg'

# # Bypasses the Imgur server security wall (prevents urlretrieve errors)
# opener = urllib.request.build_opener()
# opener.addheaders = [('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)')]
# urllib.request.install_opener(opener)

# # 2. Download the image locally using urlretrieve
# urllib.request.urlretrieve(url, filename)
# print("Image downloaded successfully!")

# # 3. Read into memory using the PIL module
# img = Image.open('chart.jpg')

# # 4. Convert the PIL image into a 3D NumPy array
# img_array = np.array(img)
# print("Image array shape:", img_array.shape) # Output will be: (481, 640, 3)

# # 5. Display the final image exactly like Aakash's video layout
# plt.grid(False)
# plt.title('A data science meme')
# plt.axis('off')
# plt.imshow(img)
# plt.show()

# %%
from PIL import Image
img = Image.open('chart.jpg')
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# An image loaded using PIL is simply a 3-dimensional numpy array containing pixel intensities for RGB channels of the image. We can convert the image into an array using `np.array`.

# %%
img_array = np.array(img)
img_array.shape
# Out:
# (481, 640, 3)

# %% [markdown]
# Displaying the image

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# We can turn off the axes & grid lines, and show a title using the releevant functions.

# %%
plt.grid(False)
plt.title("A data Science Meme")
plt.axis(False)
plt.imshow(img)
plt.show()

# %% [markdown]
# To display a part of the image, we can simply select a slice from the numpy array

# %%
plt.grid(False)
plt.axis(False)
plt.imshow(img_array[125:325, 105:305])
plt.show()

# %% [markdown]
# ### Plotting multiple charts in a grid
# Matplotlib and seaborn also support potting multiple charts in a grid, using `plt.subplots`, which returns a set of axes that can be used for plotting.
#
# Here's a single grid showing the different types of charts we have covered in this session.

# %%
yrs
# Out:
# range(2000, 2012)

# %% [markdown]
# ## CREATING A FIGURE OF SUBPLOTS

# %%
fig, axes = plt.subplots(2,3, figsize=(16,8))
plt.tight_layout(pad=4)

# Use the axes for plotting

# axis 1
axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].set_xlabel("Year")
axes[0,0].set_ylabel('yoeld(tons per hectare)')
axes[0,0].legend(['Apples', 'Oranges'])
axes[0,0].set_title('Crop Yield in Boson')

# axis 2
axes[0,1].set_title("Sepal Length vs Sepal Width")
sns.scatterplot(x=flowers_df["sepal length (cm)"],
                y=flowers_df["sepal width (cm)"],
                hue=flowers_df["species"],
                s=80,
                ax = axes[0,1])
#axes[0,1].legend(["Setosa", "Versicolour", "Virginica"], loc='upper right')

# axis 3
axes[0,2].set_title("Distribution of Sepal Width")
axes[0,2].hist([versicolour_df["sepal width (cm)"], setosa_df["sepal width (cm)"], versicolour_df["sepal width (cm)"]],
         bins=np.arange(2, 5, 0.25),
        stacked=True)

axes[0,2].legend(["Setosa", "Versicolour", "Virginica"], loc='upper right')

# axes 4
axes[1, 0].set_title("Restaurant Bills")
sns.barplot(x="day", y="total_bill", hue="sex", data=tips, ax=axes[1,0])
axes[1,0].legend(["Male", "Female"])
axes[1,0].legend(loc='upper right')

# axes 5
axes[1,1].set_title("Flight Traffic Heatmap")
sns.heatmap(flights, cmap="Blues", ax=axes[1,1])

# axes 6
axes[1,2].set_title("Data Science Meme")
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].axis(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])


plt.show()

# %%
fig.savefig("Subplots Visualizations.png")
